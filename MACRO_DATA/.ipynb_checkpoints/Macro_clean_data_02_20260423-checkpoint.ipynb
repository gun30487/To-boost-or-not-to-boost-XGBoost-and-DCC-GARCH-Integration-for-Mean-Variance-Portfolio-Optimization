# %%
import yfinance as yf
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import statsmodels.api as sm
import ta
import os

import refinitiv.dataplatform as rdp
import lseg.data as ld

data_folder = os.getcwd() + '/'
data_folder
# https://github.com/LSEG-API-Samples/Example.RDPLibrary.Python
# Out:
# '/Users/gunassavsopee/Gun/Python/TEST_MVP/MACRO_DATA/'

# %%
# GET DATA FORM COUNTRY INDEX
country = {'EK':'EZU','AU':'EWA','JP':'EWJ','UK':'EWU','US':'IVV','CH':'MCHI','IN':'INDA','VI':'VNM','TH':'THD'}
xls = pd.ExcelFile('MACRO_by_cat_sum_no_head.xlsx')

for i in country:
    df = pd.DataFrame()
    for sheet in xls.sheet_names:
        macro = pd.read_excel(xls, sheet_name=sheet)
        macro.rename(columns={'Name':'Date'},inplace=True)
        macro = macro.set_index('Date')
        macro_country = macro[[col for col in macro.columns if col[:2] == i]]
        try:
            macro_country = macro_country.iloc[:, [1, 2]]
            macro_country.columns = [sheet+'_MOM',sheet+'_YOY']
            df = df.merge(macro_country,left_index=True,right_index=True,how='outer')
            print(i +" "+ sheet)
        except:
            print(' No data for ' + i +" "+ sheet)
    df = df.asfreq('d').ffill()  # Fill missing values
    
    file_name = country[i] + '_Macro_M'
    df.to_excel(file_name + '.xlsx')
    print(file_name +' Done')
    print('_'*30)
    print('_'*30)
# Out:
# EK EXP
# EK IMP
# EK CA
# EK CPI
# EK CORE_CPI
# EK PPI
# EK UNEM
#  No data for EK RS
# EK IP
# EZU_Macro_M Done
# ______________________________
# ______________________________
# AU EXP
# AU IMP
# AU CA
# AU CPI
# AU CORE_CPI
# AU PPI
# AU UNEM
# AU RS
# AU IP
# EWA_Macro_M Done
# ______________________________
# ______________________________
# JP EXP
# JP IMP
# JP CA
# JP CPI
# JP CORE_CPI
# JP PPI
# JP UNEM
# JP RS
# JP IP
# EWJ_Macro_M Done
# ______________________________
# ______________________________
# UK EXP
# UK IMP
# UK CA
# UK CPI
# UK CORE_CPI
# UK PPI
# UK UNEM
# UK RS
# UK IP
# EWU_Macro_M Done
# ______________________________
# ______________________________
# US EXP
# US IMP
# US CA
# US CPI
# US CORE_CPI
# US PPI
# US UNEM
# US RS
# US IP
# IVV_Macro_M Done
# ______________________________
# ______________________________
# CH EXP
# CH IMP
# CH CA
# CH CPI
# CH CORE_CPI
#  No data for CH PPI
# CH UNEM
# CH RS
#  No data for CH IP
# MCHI_Macro_M Done
# ______________________________
# ______________________________
# IN EXP
# IN IMP
# IN CA
# IN CPI
#  No data for IN CORE_CPI
# IN PPI
#  No data for IN UNEM
#  No data for IN RS
# IN IP
# INDA_Macro_M Done
# ______________________________
# ______________________________
# VI EXP
# VI IMP
# VI CA
# VI CPI
#  No data for VI CORE_CPI
#  No data for VI PPI
#  No data for VI UNEM
# VI RS
# VI IP
# VNM_Macro_M Done
# ______________________________
# ______________________________
# TH EXP
# TH IMP
# TH CA
# TH CPI
# TH CORE_CPI
# TH PPI
# TH UNEM
# TH RS
# TH IP
# THD_Macro_M Done
# ______________________________
# ______________________________

# %%
#  CHECK COLUMN NAME
stocks = ['EZU','EWA','EWJ','EWU','IVV','MCHI','INDA','VNM','THD']
df = pd.DataFrame(index=range(1, 20))
for stock in stocks:
    macro = pd.read_excel(stock+'_Macro.xlsx')
    macro.rename(columns={'Name':'Date'},inplace=True)
    macro = macro.set_index('Date')
    df[stock] = pd.Series(macro.columns)

df
# Out:
#                EZU             EWA             EWJ             EWU  \
# 1            GBY2Y           GBY2Y           GBY2Y           GBY2Y
# 2            GBY5Y           GBY5Y           GBY5Y           GBY5Y
# 3           GBY10Y          GBY10Y          GBY10Y          GBY10Y
# 4         GBY10-2Y        GBY10-2Y        GBY10-2Y        GBY10-2Y
# 5      gold_M_diff     gold_M_diff     gold_M_diff     gold_M_diff
# 6       BDI_M_diff      BDI_M_diff      BDI_M_diff      BDI_M_diff
# 7       BRT_M_diff      BRT_M_diff      BRT_M_diff      BRT_M_diff
# 8   EUR/USD_M_diff  EUR/USD_M_diff  JPY/USD_M_diff  GBP/USD_M_diff
# 9          CPI_MOM         CPI_MOM         CPI_MOM         CPI_MOM
# 10         PPI_MOM         PPI_MOM         PPI_MOM         PPI_MOM
# 11         EXP_MOM         EXP_MOM         EXP_MOM         EXP_MOM
# 12         IMP_MOM         IMP_MOM         IMP_MOM         IMP_MOM
# 13          CA_MOM          CA_MOM          CA_MOM          CA_MOM
# 14        UNEM_MOM        UNEM_MOM        UNEM_MOM        UNEM_MOM
# 15          IP_MOM          IP_MOM          IP_MOM          IP_MOM
# 16             NaN          RS_MOM          RS_MOM          RS_MOM
# 17             NaN             NaN             NaN             NaN
# 18             NaN             NaN             NaN             NaN
# 19             NaN             NaN             NaN             NaN
#
#             IVV            MCHI            INDA             VNM  \
# 1         GBY2Y           GBY2Y           GBY2Y           GBY2Y
# 2         GBY5Y           GBY5Y           GBY5Y           GBY5Y
# 3        GBY10Y          GBY10Y          GBY10Y          GBY10Y
# 4      GBY10-2Y        GBY10-2Y        GBY10-2Y        GBY10-2Y
# 5   gold_M_diff     gold_M_diff     gold_M_diff     gold_M_diff
# 6    BDI_M_diff      BDI_M_diff      BDI_M_diff      BDI_M_diff
# 7    BRT_M_diff      BRT_M_diff      BRT_M_diff      BRT_M_diff
# 8    USD_M_diff  CNY/USD_M_diff  INR/USD_M_diff  VND/USD_M_diff
# 9       CPI_MOM         CPI_MOM         CPI_MOM         CPI_MOM
# 10      PPI_MOM         EXP_MOM         PPI_MOM         EXP_MOM
# 11      EXP_MOM         IMP_MOM         EXP_MOM         IMP_MOM
# 12      IMP_MOM          CA_MOM         IMP_MOM          CA_MOM
# 13       CA_MOM          RS_MOM          CA_MOM          IP_MOM
# 14     UNEM_MOM             NaN          IP_MOM          RS_MOM
# 15       IP_MOM             NaN             NaN             NaN
# 16       RS_MOM             NaN             NaN             NaN
# 17          NaN             NaN             NaN             NaN
# 18          NaN             NaN             NaN             NaN
# 19          NaN             NaN             NaN             NaN
#
#                THD
# 1            GBY2Y
# 2            GBY5Y
# 3           GBY10Y
# 4         GBY10-2Y
# 5      gold_M_diff
# 6       BDI_M_diff
# 7       BRT_M_diff
# 8   THB/USD_M_diff
# 9          CPI_MOM
# 10         PPI_MOM
# 11         EXP_MOM
# 12         IMP_MOM
# 13          CA_MOM
# 14        UNEM_MOM
# 15          IP_MOM
# 16          RS_MOM
# 17             NaN
# 18             NaN
# 19             NaN

# %%
def cleandata(df):
    df = df.astype(float)
    # df[col_name]= np.log(df[col_name]/df[col_name].shift(1))
    df = df.asfreq('d').ffill()  # Fill missing values
    df = df.dropna()
    return df

# %%
# Merge daily and monthly data
stocks = ['EZU','EWA','EWJ','EWU','IVV','MCHI','INDA','VNM','THD']
col_m = ['CPI_MOM','PPI_MOM','EXP_MOM','IMP_MOM','CA_MOM','UNEM_MOM','IP_MOM','RS_MOM']
for stock in stocks:
    macro_d = pd.read_excel(stock+'_Macro_D.xlsx')
    macro_d.rename(columns={'Unnamed: 0':'Date'},inplace=True)
    macro_d = macro_d.set_index('Date')
    
    macro_m = pd.read_excel(stock+'_Macro_M.xlsx')
    macro_m.rename(columns={'Name':'Date'},inplace=True)
    macro_m = macro_m.set_index('Date')

    macro_m_data = pd.DataFrame()
    for col in col_m:
        try:
            macro_m_data[col] = macro_m[col]
        except:
            print(f'No DATA for {col}')
    
    macro = macro_d.merge(macro_m_data,left_index=True,right_index=True,how='outer')
    macro = macro.dropna()
        
    file_name = stock + '_Macro'
    macro.to_excel(file_name + '.xlsx')
    print(file_name+' DONE')
    
    if stock == 'IVV':
        macro.to_excel('AGG_Macro.xlsx')
        print('AGG_Macro'+' DONE')
# Out:
# No DATA for RS_MOM
# EZU_Macro DONE
# EWA_Macro DONE
# EWJ_Macro DONE
# EWU_Macro DONE
# IVV_Macro DONE
# AGG_Macro DONE
# No DATA for PPI_MOM
# No DATA for UNEM_MOM
# No DATA for IP_MOM
# MCHI_Macro DONE
# No DATA for UNEM_MOM
# No DATA for RS_MOM
# INDA_Macro DONE
# No DATA for PPI_MOM
# No DATA for UNEM_MOM
# VNM_Macro DONE
# THD_Macro DONE

# %%
x = pd.read_excel('IVV_Macro.xlsx')
x = x.set_index('Date')
x
# Out:
#               VIX  GBY2Y  GBY5Y  GBY10Y  GBY10-2Y  gold_M_diff  BDI_M_diff  \
# Date
# 2010-02-03  21.60  0.883  2.407   3.707     2.824    -0.959479  -14.872611
# 2010-02-04  26.08  0.807  2.303   3.610     2.803    -4.968500  -17.889908
# 2010-02-05  26.11  0.771  2.240   3.571     2.800    -6.449205  -16.692237
# 2010-02-06  26.11  0.771  2.240   3.571     2.800    -5.903912  -13.782153
# 2010-02-07  26.11  0.771  2.240   3.571     2.800    -6.259898  -13.535032
# ...           ...    ...    ...     ...       ...          ...         ...
# 2025-12-11  14.85  3.530  3.715   4.141     0.611     3.794692   10.714286
# 2025-12-12  15.74  3.531  3.750   4.196     0.665     2.469672    8.620690
# 2025-12-13  15.74  3.531  3.750   4.196     0.665     3.139668    6.162735
# 2025-12-14  15.74  3.531  3.750   4.196     0.665     5.462572    3.764706
# 2025-12-15  16.50  3.508  3.733   4.182     0.674     5.469068    3.200000
#
#             BRT_M_diff  USD_M_diff  CPI_MOM  PPI_MOM  EXP_MOM  IMP_MOM  \
# Date
# 2010-02-03   -3.954162    2.488992    0.065    1.016   -7.069   -6.420
# 2010-02-04   -9.884451    3.005630    0.065    1.016   -7.069   -6.420
# 2010-02-05  -12.336936    3.488717    0.065    1.016   -7.069   -6.420
# 2010-02-06  -12.802768    2.851098    0.065    1.016   -7.069   -6.420
# 2010-02-07  -12.249720    3.517432    0.065    1.016   -7.069   -6.420
# ...                ...         ...      ...      ...      ...      ...
# 2025-12-11   -2.730375   -1.135495    0.295    0.914  -10.026   -5.073
# 2025-12-12    1.100502   -1.084744    0.295    0.914  -10.026   -5.073
# 2025-12-13   -0.159821   -0.897439    0.295    0.914  -10.026   -5.073
# 2025-12-14   -2.145990   -0.887456    0.295    0.914  -10.026   -5.073
# 2025-12-15   -2.427945   -1.025460    0.298   -0.064   -2.176    8.163
#
#             CA_MOM  UNEM_MOM  IP_MOM  RS_MOM
# Date
# 2010-02-03   2.264      -0.1   1.090   0.105
# 2010-02-04   2.264      -0.1   1.090   0.105
# 2010-02-05   2.264      -0.1   1.090   0.105
# 2010-02-06   2.264      -0.1   1.090   0.105
# 2010-02-07   2.264      -0.1   1.090   0.105
# ...            ...       ...     ...     ...
# 2025-12-11  -6.468       0.1  -0.137   0.502
# 2025-12-12  -6.468       0.1  -0.137   0.502
# 2025-12-13  -6.468       0.1  -0.137   0.502
# 2025-12-14  -6.468       0.1  -0.137   0.502
# 2025-12-15 -25.414       0.1   0.525   0.000
#
# [5795 rows x 17 columns]

# %%
# file_name = stock + '_Macro'
# macro.to_excel('/Users/gunassavsopee/Gun/Python/MACRO_DATA/'+ file_name + '.xlsx')
